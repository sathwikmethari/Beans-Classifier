# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('Dry_Bean_Dataset.xlsx')
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
df_num= data.select_dtypes(exclude='object')

corr_matrix = df_num.corr()
plt.figure(figsize=(10, 10))  
sns.heatmap(corr_matrix, annot=True, cmap="Reds", square=True)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
sc=StandardScaler()
sc2=StandardScaler()
x_train_sc=sc.fit_transform(x_train)
x_test_sc=sc.transform(x_test)
cols=[x for x in df_num.columns]

# %%
df_xtrain=pd.DataFrame(x_train_sc,columns=cols)
df_xtest=pd.DataFrame(x_test_sc,columns=cols)

# %%
pca=PCA()
pca2=PCA()
pca.fit(df_xtrain)
#df_pca4=pd.DataFrame(df_pcaor,columns=cols)
# Out:
# PCA()

# %%
cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)
explained_variance = pca.explained_variance_ratio_
n_components = np.argmax(cumulative_explained_variance >= 0.98) + 1
print(n_components)
# Out:
# 6

# %%
sns.histplot(y=y,color="tomato")
plt.title("Types of Beans")
plt.ylabel("Bean Type")
plt.show()

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
x_res, y_res = sm.fit_resample(x, y)

# %%
sns.histplot(y=y_res,color="tomato")
plt.title("Types of Beans")
plt.ylabel("Bean Type")
plt.show()
